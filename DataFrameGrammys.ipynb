# %% [markdown]
# <a href="https://colab.research.google.com/github/xonorKjr/programaci-/blob/main/DataFrameGrammys.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
gent = pd.DataFrame([{"Nombre":"Beyoncé","Grammys":32,"Nacionalitat":"USA","Edat":43},
                     {"Nombre":"Georg Solti","Grammys":31,"Nacionalitat":"França","Edat":85},
                     {"Nombre":"Quincy Jones","Grammys":28,"Nacionalitat":"USA","Edat":91},
                     {"Nombre":"Alison Krauss","Grammys":27,"Nacionalitat":"USA","Edat":53},
                     {"Nombre":"Chick Corea","Grammys":27,"Nacionalitat":"USA","Edat":80},


])
gent['Grammys+2'] = gent['Grammys'] + 2

edad= gent['Edat'].mean().round(2)
mes = gent[gent["Grammys"]== gent["Grammys"].max()]
menys = gent[gent["Grammys"]== gent["Grammys"].min()]
viejo= mes = gent[gent["Edat"]== gent["Edat"].max()]

print("El promig d'edat es de", edad)
print("L'artista amb més Grammys es", mes)
print("L'artista amb menys Grammys del Top 5 es", menys)
print("L'artsita amb més anys del Top 5 es", viejo)
gent
# Out:
# El promig d'edat es de 70.4
# L'artista amb més Grammys es          Nombre  Grammys Nacionalitat  Edat  Grammys+2
# 2  Quincy Jones       28          USA    91         30
# L'artista amb menys Grammys del Top 5 es           Nombre  Grammys Nacionalitat  Edat  Grammys+2
# 3  Alison Krauss       27          USA    53         29
# 4    Chick Corea       27          USA    80         29
# L'artsita amb més anys del Top 5 es          Nombre  Grammys Nacionalitat  Edat  Grammys+2
# 2  Quincy Jones       28          USA    91         30
#           Nombre  Grammys Nacionalitat  Edat  Grammys+2
# 0        Beyoncé       32          USA    43         34
# 1    Georg Solti       31       França    85         33
# 2   Quincy Jones       28          USA    91         30
# 3  Alison Krauss       27          USA    53         29
# 4    Chick Corea       27          USA    80         29
